# %% [markdown]
# ### Imports

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gymnasium as gym
import gym_anytrading
from gym_anytrading.envs import Actions

from stable_baselines3 import A2C

import quantstats as qs

# %% [markdown]
# ### Create Env

# %%
df = gym_anytrading.datasets.STOCKS_GOOGL.copy()

window_size = 10
start_index = window_size
end_index = len(df)

env = gym.make(
    'stocks-v0',
    df=df,
    window_size=window_size,
    frame_bound=(start_index, end_index)
)
# Out:
# observation_space: Box(-10000000000.0, 10000000000.0, (10, 2), float32)

# %%
print("observation_space:", env.observation_space)

# %% [markdown]
# ### Train Env

# %%
env.reset(seed=2023)
model = A2C('MlpPolicy', env, verbose=0)
model.learn(total_timesteps=1_000)

# %% [markdown]
# ### Test Env

# %%
action_stats = {Actions.Sell: 0, Actions.Buy: 0}

observation, info = env.reset(seed=2023)

while True:
    # action = env.action_space.sample()
    action, _states = model.predict(observation)

    action_stats[Actions(action)] += 1
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        break

env.close()

print("action_stats:", action_stats)
print("info:", info)
# Out:
# action_stats: {<Actions.Sell: 0>: 1228, <Actions.Buy: 1>: 1096}
# info: {'total_reward': 509.2998504638672, 'total_profit': 0.0004647836453418036, 'position': <Positions.Short: 0>}

# %% [markdown]
# ### Plot Results

# %%
plt.figure(figsize=(16, 6))
env.unwrapped.render_all()
plt.show()

# %% [markdown]
# ### Analysis Using `quantstats`

# %%
qs.extend_pandas()

net_worth = pd.Series(env.unwrapped.history['total_profit'], index=df.index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
qs.reports.html(returns, output='SB3_a2c_quantstats.html')
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2009-06-10
# End Period                 2018-08-29
# Risk-Free Rate             0.0%
# Time in Market             25.0%
#
# Cumulative Return          -99.95%
# CAGR﹪                     -43.69%
#
# Sharpe                     -4.4
# Prob. Sharpe Ratio         0.0%
# Smart Sharpe               -4.07
# Sortino                    -4.58
# Smart Sortino              -4.24
# Sortino/√2                 -3.24
# Smart Sortino/√2           -3.0
# Omega                      0.17
#
# Max Drawdown               -99.95%
# Longest DD Days            3366
# Volatility (ann.)          18.5%
# Calmar                     -0.44
# Skew                       -2.15
# Kurtosis                   20.09
#
# Expected Daily %           -0.33%
# Expected Monthly %         -6.68%
# Expected Yearly %          -53.58%
# Kelly Criterion            -104.23%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.24%
# Expected Shortfall (cVaR)  -2.24%
#
# Max Consecutive Wins       1
# Max Consecutive Losses     1
# Gain/Pain Ratio            -0.83
# Gain/Pain (1M)             -0.98
#
# Payoff Ratio               0.62
# Profit Factor              0.17
# Common Sense Ratio         0.01
# CPC Index                  0.02
# Tail Ratio                 0.03
# Outlier Win Ratio          25.6
# Outlier Loss Ratio         2.34
#
# MTD                        -6.36%
# 3M                         -15.42%
# 6M                         -38.36%
# YTD                        -46.42%
# 1Y                         -62.15%
# 3Y (ann.)                  -44.9%
# 5Y (ann.)                  -42.96%
# 10Y (ann.)                 -43.69%
# All-time (ann.)            -43.69%
#
# Best Day                   11.3%
# Worst Day                  -11.48%
# Best Month                 7.22%
# Worst Month                -17.91%
# Best Year                  -36.63%
# Worst Year                 -64.1%
#
# Avg. Drawdown              -99.95%
# Avg. Drawdown Days         3366
# Recovery Factor            7.5
# Ulcer Index                0.91
# Serenity Index             -0.08
#
# Avg. Up Month              3.55%
# Avg. Down Month            -7.06%
# Win Days %                 21.78%
# Win Month %                4.5%
# Win Quarter %              0.0%
# Win Year %                 0.0%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2009-06-12  2018-08-21  2018-08-29  3366    -99.954113        -99.950875
# <h4>Strategy Visualization</h4>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27072/1803473950.py in <module>
#       4 returns = net_worth.pct_change().iloc[1:]
#       5
# ----> 6 qs.reports.full(returns)
#       7 qs.reports.html(returns, output='SB3_a2c_quantstats.html')
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\quantstats\reports.py in full(returns, benchmark, rf, grayscale, figsize, display, compounded, periods_per_year, match_dates, **kwargs)
#     626         print("[Strategy Visualization]\nvia Matplotlib")
#     627
# --> 628     plots(
#     629         returns=returns,
#     630         benchmark=benchmark,
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\quantstats\reports.py in plots(returns, benchmark, grayscale, figsize, mode, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#    1325     )
#    1326
# -> 1327     _plots.histogram(
#    1328         returns,
#    1329         benchmark,
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\quantstats\_plotting\wrappers.py in histogram(returns, benchmark, resample, fontname, grayscale, figsize, ylabel, subtitle, compounded, savefig, show, prepare_returns)
#     654         title = ""
#     655
# --> 656     return _core.plot_histogram(
#     657         returns,
#     658         benchmark,
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\quantstats\_plotting\core.py in plot_histogram(returns, benchmark, resample, bins, fontname, grayscale, title, kde, figsize, ylabel, subtitle, compounded, savefig, show)
#     514             combined_returns = returns.copy()
#     515             if kde:
# --> 516                 _sns.kdeplot(data=combined_returns, color="black", ax=ax)
#     517             x = _sns.histplot(
#     518                 data=combined_returns,
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1726             plot_kws["color"] = color
#    1727
# -> 1728         p.plot_univariate_density(
#    1729             multiple=multiple,
#    1730             common_norm=common_norm,
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\seaborn\distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, fill, legend, estimate_kws, **plot_kws)
#     994                     )
#     995                 else:
# --> 996                     artist, = ax.plot(support, density, **artist_kws)
#     997
#     998                 artist.sticky_edges.x[:] = sticky_support
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     386
#     387         if len(tup) == 2:
# --> 388             x = _check_1d(tup[0])
#     389             y = _check_1d(tup[-1])
#     390         else:
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1316                     message='Support for multi-dimensional indexing')
#    1317
# -> 1318                 ndim = x[:, None].ndim
#    1319                 # we have definitely hit a pandas index or series object
#    1320                 # cast to a numpy array.
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    5197         # Because we ruled out integer above, we always get an arraylike here
#    5198         if result.ndim > 1:
# -> 5199             disallow_ndim_indexing(result)
#    5200
#    5201         # NB: Using _constructor._simple_new would break if MultiIndex
#
# c:\Users\zyang\Anaconda3\envs\ML\lib\site-packages\pandas\core\indexers\utils.py in disallow_ndim_indexing(result)
#     341     """
#     342     if np.ndim(result) > 1:
# --> 343         raise ValueError(
#     344             "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     345             "supported. Convert to a numpy array before indexing instead."
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.
